# %% [markdown]
# ## Import standard libraries

# %%
import torch
import torch.nn as nn  # we'll use this a lot going forward!
import torch.nn.functional as F

import numpy as np
import warnings

# Import matplotlib library and setup environment for plots
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
from matplotlib import pyplot as plt, rc

# Import pandas and set pandas DataFrame visualization parameters
from IPython.display import display
import pandas as pd
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# Set rendering parameters to use TeX font if not working on Juno app.
from pathlib import Path
import os
if not '/private/var/' in os.getcwd():
    rc('font', **{'family': 'serif', 'serif': ['Computer Modern'], 'size': 11})
    rc('text', usetex=True)
    
# Get current working directory path for the tool parent folder and print it.
parent_folder = 'Tool'
cwd = str(Path(os.getcwd()[:os.getcwd().index(parent_folder)+len(parent_folder)]))
print('Parent working directory: %s' % cwd)
# Out:
# Parent working directory: /Users/jjrr/Documents/SCA-Project/Tool

# %% [markdown]
# ## Import user defined libraries

# %%
# Import custom libraries from local folder.
import sys
sys.path.append("..")

from library.irplib import utils, eda, sdg

# %% [markdown]
# ## Data preparation

# %% [markdown]
# ### Import training dataset

# %%
# Import transformed training dataset
df = eda.import_cdm_data(os.path.join(cwd,'data','esa-challenge','train_data_transformed.csv'))

# Count number of CDMs available per event
nb_cdms = df.groupby(['event_id']).count()['time_to_tca'].to_numpy(dtype=np.int32)

# Get information summary on TS suitable for training
min_cdms = 5
print(f'Events suitable for training: {np.sum(nb_cdms>min_cdms)}'
      f' ({np.sum(nb_cdms>min_cdms)/len(nb_cdms)*100:.2f}%)')
print(f'TSs with event_id integrity for training: {np.sum(nb_cdms[nb_cdms>min_cdms]-min_cdms)}')

# Show first data points to explore data types
display(df.head(10))
# Out:
# Events suitable for training: 9400 (71.46%)
# TSs with event_id integrity for training: 104099
#   event_id  time_to_tca mission_id       risk  max_risk_estimate  \
# 0        0     1.566798          5 -10.204955          -7.834756
# 1        0     1.207494          5 -10.355758          -7.848937
# 2        0     0.952193          5 -10.345631          -7.847406
# 3        0     0.579669          5 -10.337809          -7.845880
# 4        0     0.257806          5 -10.391260          -7.852942
# 5        1     6.530455          5  -7.561299          -7.254301
# 6        1     5.561646          5  -9.315693          -7.468904
# 7        1     5.226504          5  -7.422508          -7.051001
# 8        1     3.570013          5  -9.248105          -7.327533
# 9        2     6.983474          2 -10.816161          -6.601713
#
#    max_risk_scaling  miss_distance  relative_speed  relative_position_r  \
# 0          8.602101        14923.0         13792.0                453.8
# 1          8.956374        14544.0         13792.0                474.3
# 2          8.932195        14475.0         13792.0                474.6
# 3          8.913444        14579.0         13792.0                472.7
# 4          9.036838        14510.0         13792.0                478.7
# 5          2.746782         2392.0          3434.0                 74.3
# 6          7.223137         3587.0          3434.0                 99.0
# 7          2.956639         7882.0          3434.0                -50.0
# 8          7.425994        26899.0          3434.0                -82.0
# 9         13.293159        22902.0         14348.0              -1157.6
#
#    relative_position_t  relative_position_n  relative_velocity_r  \
# 0               5976.6             -13666.8                 -7.2
# 1               5821.2             -13319.8                 -7.0
# 2               5796.2             -13256.1                 -7.0
# 3               5838.9             -13350.7                 -7.0
# 4               5811.1             -13288.0                 -7.0
# 5               2317.1               -589.4                 25.9
# 6               3475.4               -885.1                 24.7
# 7              -7638.3               1945.7                 36.8
# 8             -26067.0               6638.2                 56.8
# 9              -6306.2              21986.3                 15.8
#
#    relative_velocity_t  relative_velocity_n t_time_lastob_start  \
# 0             -12637.0              -5525.9                 1.0
# 1             -12637.0              -5525.9                 1.0
# 2             -12637.0              -5525.9                 1.0
# 3             -12637.0              -5525.9                 1.0
# 4             -12637.0              -5525.9                 1.0
# 5               -847.8              -3328.2                 1.0
# 6               -847.8              -3328.2                 1.0
# 7               -847.7              -3328.2                 1.0
# 8               -847.8              -3328.2                 1.0
# 9             -13792.0              -3957.1                 1.0
#
#   t_time_lastob_end  t_recommended_od_span  t_actual_od_span  t_obs_available  \
# 0               0.0                   3.78              3.78              459
# 1               0.0                   3.79              3.79              456
# 2               0.0                   3.79              3.80              456
# 3               0.0                   3.86              3.86              443
# 4               0.0                   3.86              3.86              440
# 5               0.0                   4.06              4.06              432
# 6               0.0                   3.91              3.91              449
# 7               0.0                   3.99              3.99              434
# 8               0.0                   4.04              4.04              430
# 9               0.0                   3.92              3.92              444
#
#    t_obs_used  t_residuals_accepted  t_weighted_rms  t_rcs_estimate  \
# 0         458                  98.9           1.265          0.4020
# 1         455                  98.5           1.270          0.4020
# 2         455                  98.5           1.257          0.4020
# 3         442                  98.4           1.254          0.4020
# 4         439                  98.8           1.340          0.4020
# 5         431                  98.9           1.447          0.4030
# 6         448                  99.0           1.447          0.4030
# 7         433                  98.9           1.383          0.4030
# 8         429                  99.0           1.402          0.4030
# 9         442                  99.4           1.094          3.4505
#
#    t_cd_area_over_mass  t_cr_area_over_mass     t_sedr    t_j2k_sma  \
# 0             1.648115             0.706590  -9.879172  6996.918867
# 1             1.607704             0.900255  -9.721584  6996.920255
# 2             1.592208             0.695163  -9.712935  6996.920553
# 3             1.608062             0.539818  -9.645910  6996.920276
# 4             1.657651             0.722942  -9.602338  6996.920446
# 5             1.595188             0.090725 -10.276501  7001.527412
# 6             1.744551             0.552328 -10.302343  7001.525780
# 7             1.701995             0.548782 -10.321625  7001.538661
# 8             1.809278             0.336598 -10.382249  7001.561205
# 9             3.042086             0.924980 -10.894082  7158.394530
#
#    t_j2k_ecc  t_j2k_inc    t_ct_r    t_cn_r    t_cn_t  t_crdot_r  t_crdot_t  \
# 0   0.003997  97.806412 -0.397969  0.292258  0.040799   0.394221  -0.999674
# 1   0.003996  97.806420 -0.073137  0.297366  0.060541   0.069652  -0.998192
# 2   0.003996  97.806418 -0.109230  0.305189  0.043711   0.107079  -0.996235
# 3   0.003997  97.806423  0.021588  0.423647  0.157544  -0.032072  -0.990913
# 4   0.003996  97.806426  0.417865  0.406002  0.246911  -0.465256  -0.983144
# 5   0.001030  97.767020 -0.134713  0.126515 -0.023597   0.108845  -0.998856
# 6   0.001029  97.767016 -0.125119  0.221214  0.011789   0.098413  -0.998694
# 7   0.001028  97.767016 -0.259827  0.194564 -0.017360   0.236605  -0.998760
# 8   0.001028  97.767002  0.025433  0.318842  0.027919  -0.050648  -0.997384
# 9   0.000860  98.523094 -0.099768  0.357995 -0.122174   0.085472  -0.999674
#
#    t_crdot_n  t_ctdot_r  t_ctdot_t  t_ctdot_n  t_ctdot_rdot  t_cndot_r  \
# 0  -0.038498  -0.981098   0.214612  -0.316493     -0.210247   0.170737
# 1  -0.052511  -0.994240  -0.029644  -0.302333      0.034030   0.179696
# 2  -0.034287  -0.996674   0.033933  -0.308501     -0.030161   0.123760
# 3  -0.149998  -0.998856  -0.059398  -0.427166      0.072214   0.228051
# 4  -0.243006  -0.999749  -0.430895  -0.405723      0.479990   0.223469
# 5   0.018619  -0.999598   0.107629  -0.126921     -0.081454  -0.096789
# 6  -0.020421  -0.999507   0.095203  -0.222805     -0.068121   0.009246
# 7   0.010202  -0.999310   0.225534  -0.196229     -0.201741  -0.017222
# 8  -0.040625  -0.999560  -0.053437  -0.319966      0.079098   0.016432
# 9   0.121504  -0.999114   0.057809  -0.353866     -0.043471  -0.025138
#
#    t_cndot_t  t_cndot_n  t_cndot_rdot  t_cndot_tdot c_object_type  \
# 0  -0.001551   0.531593      0.002117     -0.179278       UNKNOWN
# 1   0.001552   0.561142     -0.005165     -0.181036       UNKNOWN
# 2   0.019630   0.579274     -0.023726     -0.125737       UNKNOWN
# 3   0.039163   0.547564     -0.049976     -0.229497       UNKNOWN
# 4   0.118674   0.543475     -0.143542     -0.224060       UNKNOWN
# 5  -0.082136   0.810101      0.085601      0.099044        DEBRIS
# 6  -0.017973   0.815906      0.015338     -0.009128        DEBRIS
# 7  -0.019988   0.813066      0.018852      0.017768        DEBRIS
# 8  -0.049850   0.760496      0.046685     -0.015341        DEBRIS
# 9   0.087954  -0.430583     -0.088821      0.021409       UNKNOWN
#
#   c_time_lastob_start c_time_lastob_end  c_recommended_od_span  \
# 0               180.0               2.0                  15.85
# 1               180.0               2.0                  15.85
# 2               180.0               2.0                  15.85
# 3               180.0               2.0                  15.85
# 4               180.0               2.0                  15.85
# 5                 1.0               0.0                   3.28
# 6                 1.0               0.0                   3.28
# 7                 1.0               0.0                   3.44
# 8                 1.0               0.0                   3.54
# 9               180.0               2.0                  13.87
#
#    c_actual_od_span  c_obs_available  c_obs_used  c_residuals_accepted  \
# 0             15.85               15          15                 100.0
# 1             15.85               15          15                 100.0
# 2             15.85               15          15                 100.0
# 3             15.85               15          15                 100.0
# 4             15.85               15          15                 100.0
# 5              3.28               33          33                 100.0
# 6              3.28               36          36                 100.0
# 7              3.44               36          36                 100.0
# 8              3.55               33          33                 100.0
# 9             13.87               15          15                 100.0
#
#    c_weighted_rms  c_rcs_estimate  c_cd_area_over_mass  c_cr_area_over_mass  \
# 0           2.360             NaN             0.676499             0.499637
# 1           2.360             NaN             0.676499             0.499637
# 2           2.360             NaN             0.676499             0.499637
# 3           2.360             NaN             0.676499             0.499637
# 4           2.360             NaN             0.676499             0.499637
# 5           1.394          0.0045             0.307134             0.000000
# 6           1.428          0.0045             0.305194             0.000000
# 7           1.543          0.0045             0.286323             0.000000
# 8           1.650          0.0045             0.294611             0.000000
# 9           1.838             NaN             1.579769             2.227246
#
#      c_sedr    c_j2k_sma  c_j2k_ecc  c_j2k_inc    c_ct_r    c_cn_r    c_cn_t  \
# 0 -6.567277  7006.607320   0.003144  74.045735 -0.824859  0.473976 -0.002576
# 1 -6.567277  7006.621053   0.003144  74.045736 -0.818207  0.482754 -0.003578
# 2 -6.567277  7006.623524   0.003144  74.045737 -0.817408  0.483828 -0.003742
# 3 -6.567277  7006.622932   0.003144  74.045736 -0.817557  0.483678 -0.003760
# 4 -6.567277  7006.626646   0.003144  74.045736 -0.815980  0.485794 -0.004081
# 5 -4.498246  6880.652110   0.017491  82.431758 -0.858928  0.106509  0.325019
# 6 -4.566296  6880.652333   0.017494  82.431471 -0.929685 -0.031789  0.295882
# 7 -4.638379  6880.573187   0.017487  82.431405 -0.949988 -0.159227  0.029555
# 8 -4.741029  6880.588349   0.017491  82.431524 -0.896007 -0.341763  0.075631
# 9 -7.228422  7168.396928   0.001367  69.717278 -0.068526  0.636970 -0.038214
#
#    c_crdot_r  c_crdot_t  c_crdot_n  c_ctdot_r  c_ctdot_t  c_ctdot_n  \
# 0   0.825216  -0.999998   0.003565  -0.732954   0.220006  -0.814249
# 1   0.818573  -0.999998   0.004574  -0.728759   0.202595  -0.817490
# 2   0.817774  -0.999998   0.004738  -0.729083   0.201698  -0.817662
# 3   0.817923  -0.999998   0.004755  -0.728092   0.200534  -0.817883
# 4   0.816347  -0.999998   0.005077  -0.727257   0.196662  -0.818575
# 5   0.858976  -1.000000  -0.324987  -0.910190   0.993879   0.240336
# 6   0.929701  -1.000000  -0.295874  -0.965251   0.993607   0.219643
# 7   0.949971  -1.000000  -0.029337  -0.982010   0.991788   0.081376
# 8   0.895993  -1.000000  -0.075170  -0.982560   0.962694   0.243049
# 9   0.064305  -0.999989   0.036762  -0.996314   0.153806  -0.634961
#
#    c_ctdot_rdot  c_cndot_r  c_cndot_t  c_cndot_n  c_cndot_rdot  c_cndot_tdot  \
# 0     -0.220621   0.249855   0.196620   0.722186     -0.196908     -0.668487
# 1     -0.203216   0.258964   0.195718   0.721903     -0.196008     -0.674979
# 2     -0.202320   0.260092   0.195558   0.721854     -0.195849     -0.675347
# 3     -0.201155   0.259681   0.195808   0.721874     -0.196097     -0.675656
# 4     -0.197284   0.261753   0.195657   0.721794     -0.195947     -0.677041
# 5     -0.993890  -0.682288   0.812345   0.224426     -0.812406      0.803415
# 6     -0.993613  -0.582234   0.723177   0.301640     -0.723223      0.690395
# 7     -0.991781  -0.387170   0.287235   0.855166     -0.287098      0.330801
# 8     -0.962685  -0.389578   0.249596   0.811324     -0.249363      0.344542
# 9     -0.149627   0.715984  -0.159057   0.953945      0.156803     -0.723349
#
#    t_span  c_span     t_h_apo     t_h_per     c_h_apo     c_h_per  \
# 0     1.0     2.0  646.745439  590.818294  650.497251  606.443389
# 1     1.0     2.0  646.743506  590.823004  650.513314  606.454793
# 2     1.0     2.0  646.745607  590.821499  650.515082  606.457965
# 3     1.0     2.0  646.747747  590.818806  650.515635  606.456229
# 4     1.0     2.0  646.745868  590.821024  650.519613  606.459678
# 5     1.0     2.0  630.601047  616.179777  622.863863  382.166357
# 6     1.0     2.0  630.589995  616.187566  622.886965  382.143701
# 7     1.0     2.0  630.601095  616.202226  622.753693  382.118680
# 8     1.0     2.0  630.622566  616.225845  622.796659  382.106039
# 9    12.0     2.0  786.417082  774.097978  800.056782  780.463075
#
#    geocentric_latitude    azimuth  elevation  mahalanobis_distance  \
# 0           -73.574095 -23.618769   0.029910            129.430951
# 1           -73.570690 -23.618769   0.029079            271.540424
# 2           -73.570088 -23.618769   0.029079            347.899292
# 3           -73.571021 -23.618769   0.029079            435.376626
# 4           -73.570409 -23.618769   0.029079            469.178802
# 5           -54.220645 -75.708851  -0.432069              4.183398
# 6           -54.224559 -75.708851  -0.412051              7.267719
# 7           -54.181705 -75.710468  -0.613897             11.197928
# 8           -54.109782 -75.708851  -0.947480             62.058087
# 9            63.955771 -16.008858  -0.063092            115.208802
#
#    t_position_covariance_det  c_position_covariance_det  t_sigma_r  c_sigma_r  \
# 0                  13.510814                  38.329744   1.400673   5.586208
# 1                  11.645172                  38.318093   1.260385   5.569076
# 2                  10.757052                  38.315920   1.212547   5.567071
# 3                   9.429859                  38.318960   1.123559   5.567427
# 4                   8.965347                  38.317072   1.221472   5.563476
# 5                  17.927486                  36.311456   1.869822   4.182252
# 6                  17.206642                  35.403617   1.782985   4.343231
# 7                  16.925462                  38.229383   1.706974   4.580773
# 8                  15.444216                  36.716460   1.696593   4.604334
# 9                  15.229084                  42.445608   2.201549   5.549886
#
#    t_sigma_t  c_sigma_t  t_sigma_n  c_sigma_n  t_sigma_rdot  c_sigma_rdot  \
# 0   4.924475  10.903510   0.577410   3.841870     -1.914944      4.065123
# 1   4.026603  10.898258   0.588319   3.841512     -2.818890      4.059864
# 2   3.624286  10.897246   0.599902   3.841445     -3.237592      4.058849
# 3   3.101572  10.898730   0.602548   3.841549     -3.813734      4.060338
# 4   2.779490  10.897918   0.672074   3.841487     -4.194687      4.059524
# 5   5.555486  11.263600   1.555683   3.937777     -1.278861      4.438849
# 6   5.412093  10.981388   1.442052   3.746817     -1.423345      4.156707
# 7   5.416534  10.863491   1.394081   4.931810     -1.426290      4.038918
# 8   4.749726  10.233657   1.329935   4.576352     -2.081025      3.409257
# 9   4.994608  10.549895   0.496310   5.385613     -1.875151      3.681239
#
#    t_sigma_tdot  c_sigma_tdot  t_sigma_ndot  c_sigma_ndot  F10  F3M  SSN  AP
# 0     -5.498756     -1.801545     -5.813629     -0.950721   89   83   42  11
# 1     -5.585288     -1.805559     -5.831622     -0.950900   89   83   42  11
# 2     -5.633474     -1.805745     -5.820248     -0.950932   89   83   42  11
# 3     -5.714465     -1.806008     -5.836750     -0.950883   89   83   40  14
# 4     -5.607668     -1.806842     -5.738377     -0.950913   89   83   40  14
# 5     -4.964692     -1.137492     -5.472981     -3.049457   71   88    0   2
# 6     -5.051207     -1.329401     -5.592821     -3.218367   70   87   13  14
# 7     -5.131717     -1.350506     -5.630159     -2.485949   70   87   13  14
# 8     -5.135739     -1.743221     -5.681594     -2.841973   71   87   21   5
# 9     -4.670266     -1.309462     -5.550399     -1.080559   73   77   27   4

# %% [markdown]
# ### Feature engineering

# %% [markdown]
# #### Input vs output and categorical vs continuous input features segregation

# %%
# Get list of event_ids
event_ids = df['event_id'].cat.categories.values

# Initialize output features
out_features = ["risk", "max_risk_estimate"]

# Get input features
in_features = [f for f in df.columns if not f in out_features and \
               not f in ['event_id', 'mission_id', 'max_risk_scaling']]

# Separate categorical features from continuous features
cat_features = [f for f in in_features if df[f].dtype=='category']
cont_features = [f for f in in_features if not f in cat_features]

# %% [markdown]
# #### Continuous features: variability analysis per event

# %%
# Compute standard deviation, and mean of every feature per event_id.
events_std    = df[['event_id'] + cont_features].groupby(['event_id']).std()
events_mean   = df[['event_id'] + cont_features].groupby(['event_id']).mean()


# Evaluate variability of feature per event_id using the order of magnitude
events_var = pd.DataFrame(index=event_ids, columns=cont_features)

for feature in cont_features: 
    events_var[feature] = (events_mean[feature]/events_std[feature]).apply(lambda x: utils.om(x))


# Initialize and print criteria used to class features as globally constant or variable
om_criteria = 2
p_criteria = 0.1

print(f'Criteria for which a feature is considered CONSTANT:\n'
      f' (1.) - Locally (for a given event): if its mean is {om_criteria} orders of magnitude bigger than its standard deviation, or its standard deviation is 0.\n'
      f' (2.) - Globally (for the entire dataset): if criteria (1.) is met in more than {p_criteria*100:2.0f}% of the total number of events.\n')

# Get array of continuous features that are constant and variables
var_features   = [f for f in cont_features if np.sum(events_var[f]<om_criteria)/len(events_var)>p_criteria]
cons_features  = [f for f in cont_features if f not in var_features]

# Print results of analysis
print(f'Constant features: {len(cons_features)}')
for cf in cons_features: print(f' - {cf:25s} ({np.sum(events_var[cf]>=om_criteria)/len(events_var)*100:5.2f}%)')

print(f'\nVariable features: {len(var_features)}')
for vf in var_features: print(f' - {vf:25s} ({np.sum(events_var[vf]<om_criteria)/len(events_var)*100:5.2f}%)')
# Out:
# Criteria for which a feature is considered CONSTANT:
#  (1.) - Locally (for a given event): if its mean is 2 orders of magnitude bigger than its standard deviation, or its standard deviation is 0.
#  (2.) - Globally (for the entire dataset): if criteria (1.) is met in more than 10% of the total number of events.
#
# Constant features: 19
#  - relative_speed            (98.23%)
#  - relative_velocity_t       (97.45%)
#  - relative_velocity_n       (98.27%)
#  - t_rcs_estimate            (94.15%)
#  - t_j2k_sma                 (98.29%)
#  - t_j2k_ecc                 (96.62%)
#  - t_j2k_inc                 (98.29%)
#  - c_j2k_sma                 (98.29%)
#  - c_j2k_ecc                 (90.09%)
#  - c_j2k_inc                 (98.29%)
#  - t_span                    (98.29%)
#  - c_span                    (98.29%)
#  - t_h_apo                   (98.29%)
#  - t_h_per                   (98.29%)
#  - c_h_apo                   (98.29%)
#  - c_h_per                   (98.29%)
#  - geocentric_latitude       (95.96%)
#  - azimuth                   (98.27%)
#  - F3M                       (92.58%)
#
# Variable features: 74
#  - time_to_tca               (99.99%)
#  - miss_distance             (90.16%)
#  - relative_position_r       (91.90%)
#  - relative_position_t       (90.57%)
#  - relative_position_n       (90.35%)
#  - relative_velocity_r       (67.49%)
#  - t_recommended_od_span     (65.83%)
#  - t_actual_od_span          (75.51%)
#  - t_obs_available           (91.39%)
#  - t_obs_used                (93.69%)
#  - t_residuals_accepted      (10.20%)
#  - t_weighted_rms            (93.23%)
#  - t_cd_area_over_mass       (91.47%)
#  - t_cr_area_over_mass       (96.02%)
#  - t_sedr                    (58.36%)
#  - t_ct_r                    (98.21%)
#  - t_cn_r                    (99.43%)
#  - t_cn_t                    (99.74%)
#  - t_crdot_r                 (98.99%)
#  - t_crdot_t                 (43.51%)
#  - t_crdot_n                 (99.77%)
#  - t_ctdot_r                 (28.92%)
#  - t_ctdot_t                 (99.32%)
#  - t_ctdot_n                 (99.47%)
#  - t_ctdot_rdot              (99.37%)
#  - t_cndot_r                 (99.65%)
#  - t_cndot_t                 (99.73%)
#  - t_cndot_n                 (98.75%)
#  - t_cndot_rdot              (99.70%)
#  - t_cndot_tdot              (99.64%)
#  - c_recommended_od_span     (78.52%)
#  - c_actual_od_span          (79.07%)
#  - c_obs_available           (74.84%)
#  - c_obs_used                (74.93%)
#  - c_residuals_accepted      (15.99%)
#  - c_weighted_rms            (79.72%)
#  - c_rcs_estimate            (36.54%)
#  - c_cd_area_over_mass       (48.76%)
#  - c_cr_area_over_mass       (73.20%)
#  - c_sedr                    (29.80%)
#  - c_ct_r                    (86.00%)
#  - c_cn_r                    (86.41%)
#  - c_cn_t                    (91.61%)
#  - c_crdot_r                 (87.84%)
#  - c_crdot_t                 (26.59%)
#  - c_crdot_n                 (92.28%)
#  - c_ctdot_r                 (61.41%)
#  - c_ctdot_t                 (91.52%)
#  - c_ctdot_n                 (85.85%)
#  - c_ctdot_rdot              (91.56%)
#  - c_cndot_r                 (86.92%)
#  - c_cndot_t                 (90.76%)
#  - c_cndot_n                 (82.12%)
#  - c_cndot_rdot              (90.70%)
#  - c_cndot_tdot              (86.03%)
#  - elevation                 (67.28%)
#  - mahalanobis_distance      (97.63%)
#  - t_position_covariance_det (97.17%)
#  - c_position_covariance_det (80.38%)
#  - t_sigma_r                 (97.69%)
#  - c_sigma_r                 (79.69%)
#  - t_sigma_t                 (97.51%)
#  - c_sigma_t                 (81.94%)
#  - t_sigma_n                 (96.78%)
#  - c_sigma_n                 (77.68%)
#  - t_sigma_rdot              (98.78%)
#  - c_sigma_rdot              (88.05%)
#  - t_sigma_tdot              (92.82%)
#  - c_sigma_tdot              (83.53%)
#  - t_sigma_ndot              (70.47%)
#  - c_sigma_ndot              (80.86%)
#  - F10                       (67.08%)
#  - SSN                       (92.31%)
#  - AP                        (89.58%)

# %% [markdown]
# ## Time-Series Forecasting problem

# %%
def event_ts_sets(full_seq:np.ndarray, window_size:int, events_to_forecast:int=1) -> list:  
    """Get all training Time-Series sets (sequence->target) 
    associated to an event.

    Args:
        full_sequence (np.ndarray): Array containing the full sequence 
        of data for a given event.
        window_size (int): Window size of events.
        events_to_forecast (int): Number of events to forecast. Defaults to 1.

    Returns:
        list: List of tuples with sequences and labels.
    """

    # Get number of TS sets to extract from the full sequence. 
    n = len(full_seq) - (window_size + events_to_forecast)+1

    # Initialize Time-Series sets list containing tuples with sequence-target
    # for a given event.
    ts_sets = []

    # Create the list of Time-Series sets using a loop.
    for i in range(n):

        # Get sequence and target value for element i
        seq_i       = full_seq[i:i+window_size]
        target_i    = full_seq[i+window_size:i+window_size+events_to_forecast]

        # Add tuple to the output list
        ts_sets.append((seq_i, target_i))

    return ts_sets

# %%
from tqdm import tqdm

window_size = 5
events_to_forecast = 1

# Count number of CDMs (full Time-Series sequence) per event
ts_events  = df[['event_id', 'time_to_tca']].groupby(['event_id']).count().rename(columns={'time_to_tca':'nb_events'})

# Exclude those events that do not have a minimum number of CDMs equal to the window_size + events_to_forecast
ts_events = ts_events.drop(ts_events[ts_events['nb_events']<window_size+events_to_forecast].index)
events_filter = list(ts_events.index.values)

# Get time-series sets for every continuous variable feature 
# (constant features by definition do not need to be forecasted)
features_ts = {}
for f, feature in enumerate([f for f in in_features if f in var_features]):

    features_ts[feature] = []
    for event_id in tqdm(events_filter, desc=f'Extracting time-series for {feature:^25s} (Overall progress: {(f+1)/len(in_features)*100:5.1f}%)...'):
        full_seq = df[df['event_id']==event_id][feature].to_numpy()

        features_ts[feature] = features_ts[feature] + event_ts_sets(full_seq, window_size)
# Out:
# Extracting time-series for        time_to_tca        (Overall progress:   1.0%)...: 100%|██████████| 9400/9400 [00:05<00:00, 1811.99it/s]
# Extracting time-series for       miss_distance       (Overall progress:   2.0%)...: 100%|██████████| 9400/9400 [00:05<00:00, 1869.21it/s]
# Extracting time-series for      relative_speed       (Overall progress:   3.1%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1901.12it/s]
# Extracting time-series for    relative_position_r    (Overall progress:   4.1%)...: 100%|██████████| 9400/9400 [00:05<00:00, 1869.75it/s]
# Extracting time-series for    relative_position_t    (Overall progress:   5.1%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1896.61it/s]
# Extracting time-series for    relative_position_n    (Overall progress:   6.1%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1908.17it/s]
# Extracting time-series for    relative_velocity_r    (Overall progress:   7.1%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1931.29it/s]
# Extracting time-series for    relative_velocity_t    (Overall progress:   8.2%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1887.02it/s]
# Extracting time-series for    relative_velocity_n    (Overall progress:   9.2%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1940.54it/s]
# Extracting time-series for    t_time_lastob_start    (Overall progress:  10.2%)...: 100%|██████████| 9400/9400 [00:05<00:00, 1762.80it/s]
# Extracting time-series for     t_time_lastob_end     (Overall progress:  11.2%)...: 100%|██████████| 9400/9400 [00:05<00:00, 1817.76it/s]
# Extracting time-series for   t_recommended_od_span   (Overall progress:  12.2%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1916.63it/s]
# Extracting time-series for     t_actual_od_span      (Overall progress:  13.3%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1909.76it/s]
# Extracting time-series for      t_obs_available      (Overall progress:  14.3%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1965.28it/s]
# Extracting time-series for        t_obs_used         (Overall progress:  15.3%)...: 100%|██████████| 9400/9400 [00:04<00:00, 2011.93it/s]
# Extracting time-series for   t_residuals_accepted    (Overall progress:  16.3%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1892.41it/s]
# Extracting time-series for      t_weighted_rms       (Overall progress:  17.3%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1966.45it/s]
# Extracting time-series for      t_rcs_estimate       (Overall progress:  18.4%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1899.74it/s]
# Extracting time-series for    t_cd_area_over_mass    (Overall progress:  19.4%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1918.14it/s]
# Extracting time-series for    t_cr_area_over_mass    (Overall progress:  20.4%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1938.71it/s]
# Extracting time-series for          t_sedr           (Overall progress:  21.4%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1961.27it/s]
# Extracting time-series for         t_j2k_sma         (Overall progress:  22.4%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1914.73it/s]
# Extracting time-series for         t_j2k_ecc         (Overall progress:  23.5%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1918.67it/s]
# Extracting time-series for         t_j2k_inc         (Overall progress:  24.5%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1927.40it/s]
# Extracting time-series for          t_ct_r           (Overall progress:  25.5%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1911.03it/s]
# Extracting time-series for          t_cn_r           (Overall progress:  26.5%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1931.61it/s]
# Extracting time-series for          t_cn_t           (Overall progress:  27.6%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1908.92it/s]
# Extracting time-series for         t_crdot_r         (Overall progress:  28.6%)...: 100%|██████████| 9400/9400 [00:05<00:00, 1687.49it/s]
# Extracting time-series for         t_crdot_t         (Overall progress:  29.6%)...: 100%|██████████| 9400/9400 [00:05<00:00, 1815.00it/s]
# Extracting time-series for         t_crdot_n         (Overall progress:  30.6%)...: 100%|██████████| 9400/9400 [00:05<00:00, 1771.00it/s]
# Extracting time-series for         t_ctdot_r         (Overall progress:  31.6%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1922.39it/s]
# Extracting time-series for         t_ctdot_t         (Overall progress:  32.7%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1924.90it/s]
# Extracting time-series for         t_ctdot_n         (Overall progress:  33.7%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1900.56it/s]
# Extracting time-series for       t_ctdot_rdot        (Overall progress:  34.7%)...: 100%|██████████| 9400/9400 [00:05<00:00, 1863.36it/s]
# Extracting time-series for         t_cndot_r         (Overall progress:  35.7%)...: 100%|██████████| 9400/9400 [00:05<00:00, 1780.48it/s]
# Extracting time-series for         t_cndot_t         (Overall progress:  36.7%)...: 100%|██████████| 9400/9400 [00:05<00:00, 1803.35it/s]
# Extracting time-series for         t_cndot_n         (Overall progress:  37.8%)...: 100%|██████████| 9400/9400 [00:05<00:00, 1840.06it/s]
# Extracting time-series for       t_cndot_rdot        (Overall progress:  38.8%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1909.52it/s]
# Extracting time-series for       t_cndot_tdot        (Overall progress:  39.8%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1931.63it/s]
# Extracting time-series for       c_object_type       (Overall progress:  40.8%)...: 100%|██████████| 9400/9400 [00:05<00:00, 1626.23it/s]
# Extracting time-series for    c_time_lastob_start    (Overall progress:  41.8%)...: 100%|██████████| 9400/9400 [00:05<00:00, 1658.33it/s]
# Extracting time-series for     c_time_lastob_end     (Overall progress:  42.9%)...: 100%|██████████| 9400/9400 [00:05<00:00, 1703.94it/s]
# Extracting time-series for   c_recommended_od_span   (Overall progress:  43.9%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1902.88it/s]
# Extracting time-series for     c_actual_od_span      (Overall progress:  44.9%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1982.19it/s]
# Extracting time-series for      c_obs_available      (Overall progress:  45.9%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1959.23it/s]
# Extracting time-series for        c_obs_used         (Overall progress:  46.9%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1942.86it/s]
# Extracting time-series for   c_residuals_accepted    (Overall progress:  48.0%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1969.94it/s]
# Extracting time-series for      c_weighted_rms       (Overall progress:  49.0%)...: 100%|██████████| 9400/9400 [00:04<00:00, 2005.23it/s]
# Extracting time-series for      c_rcs_estimate       (Overall progress:  50.0%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1994.60it/s]
# Extracting time-series for    c_cd_area_over_mass    (Overall progress:  51.0%)...: 100%|██████████| 9400/9400 [00:04<00:00, 2004.32it/s]
# Extracting time-series for    c_cr_area_over_mass    (Overall progress:  52.0%)...: 100%|██████████| 9400/9400 [00:04<00:00, 2020.50it/s]
# Extracting time-series for          c_sedr           (Overall progress:  53.1%)...: 100%|██████████| 9400/9400 [00:04<00:00, 2064.26it/s]
# Extracting time-series for         c_j2k_sma         (Overall progress:  54.1%)...: 100%|██████████| 9400/9400 [00:04<00:00, 2010.13it/s]
# Extracting time-series for         c_j2k_ecc         (Overall progress:  55.1%)...: 100%|██████████| 9400/9400 [00:04<00:00, 2033.61it/s]
# Extracting time-series for         c_j2k_inc         (Overall progress:  56.1%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1954.14it/s]
# Extracting time-series for          c_ct_r           (Overall progress:  57.1%)...: 100%|██████████| 9400/9400 [00:04<00:00, 2014.75it/s]
# Extracting time-series for          c_cn_r           (Overall progress:  58.2%)...: 100%|██████████| 9400/9400 [00:04<00:00, 2035.05it/s]
# Extracting time-series for          c_cn_t           (Overall progress:  59.2%)...: 100%|██████████| 9400/9400 [00:04<00:00, 2012.49it/s]
# Extracting time-series for         c_crdot_r         (Overall progress:  60.2%)...: 100%|██████████| 9400/9400 [00:04<00:00, 2030.29it/s]
# Extracting time-series for         c_crdot_t         (Overall progress:  61.2%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1999.97it/s]
# Extracting time-series for         c_crdot_n         (Overall progress:  62.2%)...: 100%|██████████| 9400/9400 [00:04<00:00, 2052.47it/s]
# Extracting time-series for         c_ctdot_r         (Overall progress:  63.3%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1984.78it/s]
# Extracting time-series for         c_ctdot_t         (Overall progress:  64.3%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1986.29it/s]
# Extracting time-series for         c_ctdot_n         (Overall progress:  65.3%)...: 100%|██████████| 9400/9400 [00:04<00:00, 2033.21it/s]
# Extracting time-series for       c_ctdot_rdot        (Overall progress:  66.3%)...: 100%|██████████| 9400/9400 [00:04<00:00, 2042.56it/s]
# Extracting time-series for         c_cndot_r         (Overall progress:  67.3%)...: 100%|██████████| 9400/9400 [00:04<00:00, 2016.88it/s]
# Extracting time-series for         c_cndot_t         (Overall progress:  68.4%)...: 100%|██████████| 9400/9400 [00:04<00:00, 2052.29it/s]
# Extracting time-series for         c_cndot_n         (Overall progress:  69.4%)...: 100%|██████████| 9400/9400 [00:04<00:00, 2019.31it/s]
# Extracting time-series for       c_cndot_rdot        (Overall progress:  70.4%)...: 100%|██████████| 9400/9400 [00:04<00:00, 2006.45it/s]
# Extracting time-series for       c_cndot_tdot        (Overall progress:  71.4%)...: 100%|██████████| 9400/9400 [00:04<00:00, 2036.23it/s]
# Extracting time-series for          t_span           (Overall progress:  72.4%)...: 100%|██████████| 9400/9400 [00:04<00:00, 2007.23it/s]
# Extracting time-series for          c_span           (Overall progress:  73.5%)...: 100%|██████████| 9400/9400 [00:04<00:00, 2037.56it/s]
# Extracting time-series for          t_h_apo          (Overall progress:  74.5%)...: 100%|██████████| 9400/9400 [00:04<00:00, 2031.24it/s]
# Extracting time-series for          t_h_per          (Overall progress:  75.5%)...: 100%|██████████| 9400/9400 [00:04<00:00, 2069.59it/s]
# Extracting time-series for          c_h_apo          (Overall progress:  76.5%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1923.77it/s]
# Extracting time-series for          c_h_per          (Overall progress:  77.6%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1947.05it/s]
# Extracting time-series for    geocentric_latitude    (Overall progress:  78.6%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1966.97it/s]
# Extracting time-series for          azimuth          (Overall progress:  79.6%)...: 100%|██████████| 9400/9400 [00:04<00:00, 2014.86it/s]
# Extracting time-series for         elevation         (Overall progress:  80.6%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1964.82it/s]
# Extracting time-series for   mahalanobis_distance    (Overall progress:  81.6%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1983.34it/s]
# Extracting time-series for t_position_covariance_det (Overall progress:  82.7%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1948.53it/s]
# Extracting time-series for c_position_covariance_det (Overall progress:  83.7%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1913.14it/s]
# Extracting time-series for         t_sigma_r         (Overall progress:  84.7%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1962.37it/s]
# Extracting time-series for         c_sigma_r         (Overall progress:  85.7%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1912.20it/s]
# Extracting time-series for         t_sigma_t         (Overall progress:  86.7%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1985.08it/s]
# Extracting time-series for         c_sigma_t         (Overall progress:  87.8%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1969.89it/s]
# Extracting time-series for         t_sigma_n         (Overall progress:  88.8%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1980.84it/s]
# Extracting time-series for         c_sigma_n         (Overall progress:  89.8%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1928.68it/s]
# Extracting time-series for       t_sigma_rdot        (Overall progress:  90.8%)...: 100%|██████████| 9400/9400 [00:04<00:00, 2031.32it/s]
# Extracting time-series for       c_sigma_rdot        (Overall progress:  91.8%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1951.87it/s]
# Extracting time-series for       t_sigma_tdot        (Overall progress:  92.9%)...: 100%|██████████| 9400/9400 [00:04<00:00, 2080.13it/s]
# Extracting time-series for       c_sigma_tdot        (Overall progress:  93.9%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1931.83it/s]
# Extracting time-series for       t_sigma_ndot        (Overall progress:  94.9%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1944.84it/s]
# Extracting time-series for       c_sigma_ndot        (Overall progress:  95.9%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1948.47it/s]
# Extracting time-series for            F10            (Overall progress:  96.9%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1934.06it/s]
# Extracting time-series for            F3M            (Overall progress:  98.0%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1987.32it/s]
# Extracting time-series for            SSN            (Overall progress:  99.0%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1960.15it/s]
# Extracting time-series for            AP             (Overall progress: 100.0%)...: 100%|██████████| 9400/9400 [00:04<00:00, 1912.03it/s]

# %%
# Get all columns from the dataset
features_groups = {
    "targets": [
        "risk", "max_risk_estimate", "max_risk_scaling"
        ],
    "ids": [
        "event_id", "mission_id"
        ],
    "conjunction": [
        "time_to_tca", "c_object_type", "miss_distance", "mahalanobis_distance", 
        "geocentric_latitude", "azimuth", "elevation",
        "F10", "F3M", "SSN", "AP"
        ],
    "relative_state": [
        "relative_position_r", "relative_position_t", "relative_position_n",
        "relative_velocity_r", "relative_velocity_t", "relative_velocity_n",
        "relative_speed"
        ],
    "objects": {
        "coefficients": [
            "cd_area_over_mass", "cr_area_over_mass"
        ],
        "covariance": [
            "ct_r", "cn_r", "cn_t",
            "crdot_r", "crdot_t", "crdot_n",
            "ctdot_r", "ctdot_t", "ctdot_n",
            "cndot_r", "cndot_t", "cndot_n",
            "ctdot_rdot", "cndot_rdot", "cndot_tdot",
            "sigma_r", "sigma_t", "sigma_n",
            "sigma_rdot", "sigma_tdot", "sigma_ndot" 
        ],
        "orb_elements": [
            "h_apo", "h_per", "j2k_ecc", "j2k_inc", "j2k_sma"
        ],
        "miscellaneous": [
            "span", "actual_od_span", "recommended_od_span", "obs_available", "obs_used",
            "time_lastob_end", "time_lastob_start", "position_covariance_det", 
            "rcs_estimate", "sedr", "residuals_accepted", "weighted_rms"
        ]
    }
}

# %% [markdown]
# ### Converting data from Pandas DataFrame to Pytorch Tensors

# %%
# Initialize output features
out_features = ["risk", "max_risk_estimate"]

# Get input features
in_features = [f for f in df.columns if not f in out_features and \
               not f in ['event_id', 'mission_id']]

# Separate categorical features from continuous features
cat_features = [f for f in in_features if df[f].dtype=='category']
cont_features = [f for f in in_features if not f in cat_features]

# %% [markdown]
# #### Embedding categorical input features
#
# An embedding is a vector representation of a categorical variable. The representation of this vector is computed through the use of NN models/techniques that take into account potential relation between categories in order to create the vector representation for each category.
#
# In practice, an embedding matrix is a lookup table for a vector. Each row of an embedding matrix is a vector for a unique category.
#
# The main advantadge of using embeddings instead of One Hot/Dummy Encoding techniques (one column per unique value of categorical feature with 0s and 1s) is that it can preserve the natural order and common relationships between the categorical features. For example, we could represent the days of the week with 4 floating-point numbers each, and two consecutive days would look more similar than two weekdays that are days apart from each other.
#
#
# The rule of thumb for determining the embedding size (number of elemens per array) is to divide the number of unique entries in each column by 2, but not to exceed 50.

# %%
# This will set embedding sizes for the categorical columns:
# an embedding size is the length of the array into which every category
# is converted
cat_szs = [len(df[f].cat.categories) for f in cat_features]
emb_szs = [(size, min(50, (size+1)//2)) for size in cat_szs]

for f, feature in enumerate(cat_features):
    print(f'Feature {feature:20s} Embedding size: {emb_szs[f]} '
          f'(Unique vectors: {emb_szs[f][0]} | Length: {emb_szs[f][1]})')
# Out:
# Feature t_time_lastob_start  Embedding size: (3, 2) (Unique vectors: 3 | Length: 2)
# Feature t_time_lastob_end    Embedding size: (3, 2) (Unique vectors: 3 | Length: 2)
# Feature c_object_type        Embedding size: (5, 3) (Unique vectors: 5 | Length: 3)
# Feature c_time_lastob_start  Embedding size: (3, 2) (Unique vectors: 3 | Length: 2)
# Feature c_time_lastob_end    Embedding size: (3, 2) (Unique vectors: 3 | Length: 2)

# %%
from torch.utils.data import TensorDataset, DataLoader

# Covert continuous features to a tensor
conts = np.stack([df[f].values for f in cont_features], 1)
conts = torch.tensor(conts, dtype=torch.float)

# Convert categorical variables to a tensor
cats = torch.tensor(cat_features, dtype=torch.int64) 

# Convert target features to a tensor
y = torch.tensor(df[out_features].values, dtype=torch.float).reshape(-1,1)


# # Get input data and target data
# data    = df[in_features].values
# target  = df[out_features].values

# # Create tensor using TensorDataset from the input and target features.
# cdm_td = TensorDataset(torch.FloatTensor(data), torch.FloatTensor(target))
# print(cdm_td[0])

# %%
class LSTM(nn.Module):
    def __init__(self, input_size=1, hidden_size=50, out_size=1):
        super().__init__()
        self.hidden_size = hidden_size
        
        # Add an LSTM layer:
        self.lstm = nn.LSTM(input_size,hidden_size)
        
        # Add a fully-connected layer:
        self.linear = nn.Linear(hidden_size,out_size)
        
        # Initialize h0 and c0:
        self.hidden = (torch.zeros(1,1,hidden_size),
                       torch.zeros(1,1,hidden_size))
    
    def forward(self,seq):
        lstm_out, self.hidden = self.lstm(
            seq.view(len(seq), 1, -1), self.hidden)
        pred = self.linear(lstm_out.view(len(seq),-1))
        return pred[-1]   # we only care about the last prediction

# %%
class TabularModel(nn.Module):

    def __init__(self, emb_szs, n_cont, out_sz, layers, p=0.5):
        
        # Inherit attributes from nn.Module class
        super().__init__()
        
        #############################################################################
        # Instanciate functions to use on the forward operation:
        
        # self.embeds: Creates a list of pre-configured Embedding operations (it is 
        # configured by passing the number of categories ni and the length of the 
        # embedding nf)
        self.embeds = nn.ModuleList([nn.Embedding(ni, nf) for ni,nf in emb_szs])
        
        # self.emb_drop: Cancels a proportion p of the embeddings.
        self.emb_drop = nn.Dropout(p)
        
        # self.bn_cont = Normalizes continuous features. This function is configured
        # by passing the number of continuous features to normalize.
        self.bn_cont = nn.BatchNorm1d(n_cont)
        
        #############################################################################
        # Count total number of embeddings (Total number of vector components for
        # every feature)
        n_emb = sum((nf for ni,nf in emb_szs))
        
        # Compute total number of inputs to pass to the initial layer (data point = 
        # Nb. of embeddings + Nb. of continuous variables)
        n_in = n_emb + n_cont
        
        # Run through every layer to set up the operations to perform per layer.
        # (i.e. layers=[100, 50, 200])
        layerlist = []
        for l, n_neurons in enumerate(layers):
            # On layer l, which contains n_neurons, perform the following operations:
            # 1. Apply linear neural network regression (z = Sum(wi*xi+bi))
            layerlist.append(nn.Linear(n_in,n_neurons))
            
            # 2. Apply ReLU activation function (al(z))
            layerlist.append(nn.ReLU(inplace=True))
            
            # 3. Normalize data using the n_neurons
            layerlist.append(nn.BatchNorm1d(n_neurons))
            
            # 4. Cancel out a random proportion p of the neurons to avoid overfitting
            layerlist.append(nn.Dropout(p))
            
            # 5. Set new number of input features n_in for the next layer l+1.
            n_in = n_neurons
        
        # Set the last layer of the list which corresponds to the final output
        layerlist.append(nn.Linear(layers[-1],out_sz))
        
        # Instantiate layers as a Neural Network sequential task
        self.layers = nn.Sequential(*layerlist)
    
    def forward(self, x_cat, x_cont):
        # Initialize embeddings list
        embeddings = []
        
        # Apply embedding function e from self.embeds to the category i
        # in x_cat array
        for i,e in enumerate(self.embeds):
            embeddings.append(e(x_cat[:,i]))
        
        # Concatenate embedding sections into 1
        x = torch.cat(embeddings, 1)
        
        # Apply dropout function to to the embeddings torch
        x = self.emb_drop(x)
        
        # Normalize continuous variables
        x_cont = self.bn_cont(x_cont)
        
        # Concatenate embeddings with continuous variables into one torch
        x = torch.cat([x, x_cont], 1)
        
        # Process all data points with the layers functions (sequential of operations)
        x = self.layers(x)
        
        return x

# %% [markdown]
# ## Save the trained model to a file
# Right now <strong><tt>model</tt></strong> has been trained and validated, and seems to correctly classify an iris 97% of the time. Let's save this to disk.<br>
# The tools we'll use are <a href='https://pytorch.org/docs/stable/torch.html#torch.save'><strong><tt>torch.save()</tt></strong></a> and <a href='https://pytorch.org/docs/stable/torch.html#torch.load'><strong><tt>torch.load()</tt></strong></a><br>
#
# There are two basic ways to save a model.<br>
#
# The first saves/loads the `state_dict` (learned parameters) of the model, but not the model class. The syntax follows:<br>
# <tt><strong>Save:</strong>&nbsp;torch.save(model.state_dict(), PATH)<br><br>
# <strong>Load:</strong>&nbsp;model = TheModelClass(\*args, \*\*kwargs)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;model.load_state_dict(torch.load(PATH))<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;model.eval()</tt>
#
# The second saves the entire model including its class and parameters as a pickle file. Care must be taken if you want to load this into another notebook to make sure all the target data is brought in properly.<br>
# <tt><strong>Save:</strong>&nbsp;torch.save(model, PATH)<br><br>
# <strong>Load:</strong>&nbsp;model = torch.load(PATH))<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;model.eval()</tt>
#
# In either method, you must call <tt>model.eval()</tt> to set dropout and batch normalization layers to evaluation mode before running inference. Failing to do this will yield inconsistent inference results.
#
# For more information visit https://pytorch.org/tutorials/beginner/saving_loading_models.html
